# %%
# !pip install -q transformers
from transformers import pipeline
# Out:
#      |████████████████████████████████| 4.9 MB 2.1 MB/s
#      |████████████████████████████████| 163 kB 48.2 MB/s
#      |████████████████████████████████| 6.6 MB 38.6 MB/s

# %%
model = pipeline(model="kkotkar1/finetuning-review")
# Out:
# Downloading:   0%|          | 0.00/993 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.86k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/347 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/669k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
data = ["This coursewas okay to learn. It can be challenging at times but hardwork is always must in these type of courses."]
model(data)
# Out:
# [{'label': 'LABEL_5', 'score': 0.708544135093689}]
